# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
merged_data = merge_data_from_different_sensors_in_same_building('Data/NORD', frequency='10min')
merged_data = merge_sensor_and_power_data(merged_data, pd.read_csv('Processed_Data/north_power_consumption_data.csv'))
merged_data.to_csv('Data/merged_nord_with_power.csv', index=False)
